# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import re
import sys
import random
import subprocess
import json
import pickle
import argparse

import numpy as np
import pandas as pd
import seaborn as sns

from tqdm import tqdm
from joblib import Parallel, delayed
from collections import OrderedDict

import matplotlib
# matplotlib.pyplot.switch_backend('agg')

from bar import generate_bar, render_bar
from line import generate_line, render_line
from pie import generate_pie, render_pie

# %matplotlib inline

# %% [markdown]
# ### Create user bar chart

# %%
data, style = generate_bar()

# %%
data
# Out:
#          comin'  series               toast
# 0  4.386535e+09       1           courtroom
# 1  6.648994e+09       2           courtroom
# 2  3.416241e+09       1       individuality
# 3  3.512452e+09       2       individuality
# 4  6.489249e+09       1                 bag
# 5  3.107834e+09       2                 bag
# 6  3.940679e+09       1  stress-temperature
# 7  8.571393e+09       2  stress-temperature

# %%
style
# Out:
# {'fg_luminosity': None,
#  'bg_luminosity': 'bright',
#  'num_categories': 4,
#  'num_series': 2,
#  'value_scale': 'exp',
#  'orientation': 'vertical',
#  'hex_colors': ['#60e064', '#13d37c'],
#  'axes_style': 'white',
#  'axes_facecolor': '#ffffff',
#  'textures': ['/', 'x'],
#  'has_bar_border': True,
#  'bar_scale': 0.7669447033654331,
#  'legend_labels': ['dark', 'menu'],
#  'legend_position': 'left',
#  'category_title': 'toast',
#  'category_labels': ['courtroom',
#   'individuality',
#   'bag',
#   'stress-temperature'],
#  'value_title': "comin'",
#  'label_rotation': 0}

# %%
render_bar(data, style) # You can also render it.

# %% [markdown]
# ### Creat user horizontal chart

# %%
data, style = generate_bar()

# %%
render_bar(data, style)

# %% [markdown]
# ### Create pie chart

# %%
data, style = generate_pie()

# %%
render_pie(data, style)

# %% [markdown]
# ### Create line chart

# %%
data, style = generate_line()

# %%
render_line(data, style)
